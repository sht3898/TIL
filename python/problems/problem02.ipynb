# %% [markdown]
# # 모든코인 상승장? 하락장?
# > 최고가와 최저가의 차이를 변동폭으로 정의할 때 (시가 + 변동폭)이 최고가 보다 높을 경우 "상승장", 그렇지 않은 경우 "하락장" 문자열을 출력하라.
#
#
# |Key Name|Description|
# |------|---|
# |opeing_price|최근 24시간 내 시작 거래금액|
# |closing_price|최근 24시간 내 마지막 거래금액|
# |min_price|최근 24시간 내 최저 거래금액|
# |max_price|최근 24시간 내 최고 거래금액|

# %%
import pprint
import requests
url = "https://api.bithumb.com/public/ticker/all"
data = requests.get(url).json()['data']
pprint.pprint(data)
# Out:
# {'ABT': {'24H_fluctate': '3',
#          '24H_fluctate_rate': '1.02',
#          'average_price': '301.8397',
#          'buy_price': '297',
#          'closing_price': '297',
#          'max_price': '318',
#          'min_price': '284',
#          'opening_price': '294',
#          'sell_price': '300',
#          'units_traded': '1494833.68021994',
#          'volume_1day': '1494833.68021994',
#          'volume_7day': '10466996.262698205152496239'},
#  'ADA': {'24H_fluctate': '5.7',
#          '24H_fluctate_rate': '6.18',
#          'average_price': '96.3745',
#          'buy_price': '97',
#          'closing_price': '97.8',
#          'max_price': '103',
#          'min_price': '91.3',
#          'opening_price': '92.1',
#          'sell_price': '97.8',
#          'units_traded': '6171566.76509911',
#          'volume_1day': '6171566.76509911',
#          'volume_7day': '63717846.69211858'},
#  'AE': {'24H_fluctate': '14',
#         '24H_fluctate_rate': '2.72',
#         'average_price': '534.498',
#         'buy_price': '525',
#         'closing_price': '528',
#         'max_price': '570',
#         'min_price': '510',
#         'opening_price': '514',
#         'sell_price': '528',
#         'units_traded': '423315.98135147',
#         'volume_1day': '423315.98135147',
#         'volume_7day': '2469554.563717204196713173'},
#  'AMO': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '0.6409',
#          'buy_price': '0.64',
#          'closing_price': '0.65',
#          'max_price': '0.66',
#          'min_price': '0.61',
#          'opening_price': '0.65',
#          'sell_price': '0.65',
#          'units_traded': '318113658.18297477',
#          'volume_1day': '318113658.18297477',
#          'volume_7day': '3298114614.239424469475093072'},
#  'ANKR': {'24H_fluctate': '0.5',
#           '24H_fluctate_rate': '4.80',
#           'average_price': '10.5829',
#           'buy_price': '10.7',
#           'closing_price': '10.9',
#           'max_price': '11.1',
#           'min_price': '10.1',
#           'opening_price': '10.4',
#           'sell_price': '10.9',
#           'units_traded': '90443847.48962948',
#           'volume_1day': '90443847.48962948',
#           'volume_7day': '688391883.031625913155368309'},
#  'APIS': {'24H_fluctate': '0.03',
#           '24H_fluctate_rate': '1.78',
#           'average_price': '1.7365',
#           'buy_price': '1.7',
#           'closing_price': '1.71',
#           'max_price': '1.9',
#           'min_price': '1.66',
#           'opening_price': '1.68',
#           'sell_price': '1.71',
#           'units_traded': '65179034.01779579',
#           'volume_1day': '65179034.01779579',
#           'volume_7day': '297883933.661810022513315604'},
#  'ARN': {'24H_fluctate': '6',
#          '24H_fluctate_rate': '1.13',
#          'average_price': '545.9408',
#          'buy_price': '536',
#          'closing_price': '536',
#          'max_price': '586',
#          'min_price': '516',
#          'opening_price': '530',
#          'sell_price': '542',
#          'units_traded': '295016.57452498',
#          'volume_1day': '295016.57452498',
#          'volume_7day': '1699583.92723984'},
#  'AUTO': {'24H_fluctate': '0',
#           '24H_fluctate_rate': '0.00',
#           'average_price': '1.6692',
#           'buy_price': '1.66',
#           'closing_price': '1.68',
#           'max_price': '1.73',
#           'min_price': '1.62',
#           'opening_price': '1.68',
#           'sell_price': '1.68',
#           'units_traded': '25227057.58915438',
#           'volume_1day': '25227057.58915438',
#           'volume_7day': '314661924.087213603262875436'},
#  'BAT': {'24H_fluctate': '-3',
#          '24H_fluctate_rate': '-1.05',
#          'average_price': '290.6684',
#          'buy_price': '282',
#          'closing_price': '281',
#          'max_price': '305',
#          'min_price': '276',
#          'opening_price': '284',
#          'sell_price': '285',
#          'units_traded': '679894.94052239',
#          'volume_1day': '679894.94052239',
#          'volume_7day': '8790500.767517355292766026'},
#  'BCD': {'24H_fluctate': '294',
#          '24H_fluctate_rate': '15.27',
#          'average_price': '2182.9938',
#          'buy_price': '2218',
#          'closing_price': '2219',
#          'max_price': '2367',
#          'min_price': '1872',
#          'opening_price': '1925',
#          'sell_price': '2220',
#          'units_traded': '831211.3932138',
#          'volume_1day': '831211.3932138',
#          'volume_7day': '1594297.63769003'},
#  'BCH': {'24H_fluctate': '27900',
#          '24H_fluctate_rate': '8.10',
#          'average_price': '370271.5713',
#          'buy_price': '371300',
#          'closing_price': '372000',
#          'max_price': '393600',
#          'min_price': '338000',
#          'opening_price': '344100',
#          'sell_price': '372000',
#          'units_traded': '37403.96515795',
#          'volume_1day': '37403.96515795',
#          'volume_7day': '215567.18018977'},
#  'BHP': {'24H_fluctate': '9',
#          '24H_fluctate_rate': '0.52',
#          'average_price': '1765.8347',
#          'buy_price': '1734',
#          'closing_price': '1738',
#          'max_price': '1871',
#          'min_price': '1680',
#          'opening_price': '1729',
#          'sell_price': '1738',
#          'units_traded': '712430.22138545',
#          'volume_1day': '712430.22138545',
#          'volume_7day': '1450923.10677654'},
#  'BSV': {'24H_fluctate': '15200',
#          '24H_fluctate_rate': '10.60',
#          'average_price': '151754.1427',
#          'buy_price': '158400',
#          'closing_price': '158500',
#          'max_price': '163600',
#          'min_price': '139100',
#          'opening_price': '143300',
#          'sell_price': '158500',
#          'units_traded': '75359.99168912',
#          'volume_1day': '75359.99168912',
#          'volume_7day': '298096.14604875'},
#  'BTC': {'24H_fluctate': '596000',
#          '24H_fluctate_rate': '4.84',
#          'average_price': '12792778.9217',
#          'buy_price': '12892000',
#          'closing_price': '12895000',
#          'max_price': '13451000',
#          'min_price': '12110000',
#          'opening_price': '12299000',
#          'sell_price': '12895000',
#          'units_traded': '12459.4671038',
#          'volume_1day': '12459.4671038',
#          'volume_7day': '89822.61480572'},
#  'BTG': {'24H_fluctate': '120',
#          '24H_fluctate_rate': '0.40',
#          'average_price': '29584.2886',
#          'buy_price': '29430',
#          'closing_price': '29430',
#          'max_price': '30800',
#          'min_price': '27800',
#          'opening_price': '29310',
#          'sell_price': '29690',
#          'units_traded': '21601.47123421',
#          'volume_1day': '21601.47123421',
#          'volume_7day': '239073.71594281'},
#  'BTT': {'24H_fluctate': '0.02',
#          '24H_fluctate_rate': '1.48',
#          'average_price': '1.3635',
#          'buy_price': '1.36',
#          'closing_price': '1.37',
#          'max_price': '1.53',
#          'min_price': '1.21',
#          'opening_price': '1.35',
#          'sell_price': '1.37',
#          'units_traded': '362455252.17916606',
#          'volume_1day': '362455252.17916606',
#          'volume_7day': '1522042527.89765152'},
#  'BZNT': {'24H_fluctate': '0.3',
#           '24H_fluctate_rate': '1.32',
#           'average_price': '22.8003',
#           'buy_price': '22.7',
#           'closing_price': '22.9',
#           'max_price': '23.4',
#           'min_price': '22.2',
#           'opening_price': '22.6',
#           'sell_price': '22.9',
#           'units_traded': '3918037.51795373',
#           'volume_1day': '3918037.51795373',
#           'volume_7day': '86871764.065866411712033483'},
#  'CMT': {'24H_fluctate': '1.5',
#          '24H_fluctate_rate': '2.40',
#          'average_price': '63.8993',
#          'buy_price': '64',
#          'closing_price': '64',
#          'max_price': '67.7',
#          'min_price': '60.6',
#          'opening_price': '62.5',
#          'sell_price': '64.2',
#          'units_traded': '11823839.22836907',
#          'volume_1day': '11823839.22836907',
#          'volume_7day': '311718564.299722002361467615'},
#  'CON': {'24H_fluctate': '0.2',
#          '24H_fluctate_rate': '1.44',
#          'average_price': '14.0551',
#          'buy_price': '13.8',
#          'closing_price': '14',
#          'max_price': '14.5',
#          'min_price': '13.6',
#          'opening_price': '13.8',
#          'sell_price': '13.9',
#          'units_traded': '146448730.11985804',
#          'volume_1day': '146448730.11985804',
#          'volume_7day': '1187798819.956518216257690364'},
#  'CTXC': {'24H_fluctate': '-1',
#           '24H_fluctate_rate': '-0.20',
#           'average_price': '498.5846',
#           'buy_price': '485',
#           'closing_price': '487',
#           'max_price': '514',
#           'min_price': '481',
#           'opening_price': '488',
#           'sell_price': '487',
#           'units_traded': '402516.87353165',
#           'volume_1day': '402516.87353165',
#           'volume_7day': '8783345.592256528074863446'},
#  'DAC': {'24H_fluctate': '-0.09',
#          '24H_fluctate_rate': '-1.57',
#          'average_price': '5.7943',
#          'buy_price': '5.62',
#          'closing_price': '5.61',
#          'max_price': '6.04',
#          'min_price': '5.53',
#          'opening_price': '5.7',
#          'sell_price': '5.69',
#          'units_traded': '24889369.08504134',
#          'volume_1day': '24889369.08504134',
#          'volume_7day': '809111810.610607000124730197'},
#  'DACC': {'24H_fluctate': '0',
#           '24H_fluctate_rate': '0.00',
#           'average_price': '0.1648',
#           'buy_price': '0.16',
#           'closing_price': '0.17',
#           'max_price': '0.17',
#           'min_price': '0.15',
#           'opening_price': '0.17',
#           'sell_price': '0.17',
#           'units_traded': '403964753.65345881',
#           'volume_1day': '403964753.65345881',
#           'volume_7day': '2761294816.98181084'},
#  'DASH': {'24H_fluctate': '8400',
#           '24H_fluctate_rate': '5.45',
#           'average_price': '160790.9706',
#           'buy_price': '162400',
#           'closing_price': '162500',
#           'max_price': '170000',
#           'min_price': '149100',
#           'opening_price': '154100',
#           'sell_price': '162500',
#           'units_traded': '1429296.15346835',
#           'volume_1day': '1429296.15346835',
#           'volume_7day': '11476896.23253245'},
#  'ELF': {'24H_fluctate': '6',
#          '24H_fluctate_rate': '3.82',
#          'average_price': '161.7666',
#          'buy_price': '163',
#          'closing_price': '163',
#          'max_price': '170',
#          'min_price': '154',
#          'opening_price': '157',
#          'sell_price': '165',
#          'units_traded': '1037012.89562632',
#          'volume_1day': '1037012.89562632',
#          'volume_7day': '10296690.797307427790253715'},
#  'ENJ': {'24H_fluctate': '3',
#          '24H_fluctate_rate': '2.54',
#          'average_price': '120.3001',
#          'buy_price': '120',
#          'closing_price': '121',
#          'max_price': '126',
#          'min_price': '115',
#          'opening_price': '118',
#          'sell_price': '121',
#          'units_traded': '14604509.59574148',
#          'volume_1day': '14604509.59574148',
#          'volume_7day': '69360173.972952741951775443'},
#  'EOS': {'24H_fluctate': '-10',
#          '24H_fluctate_rate': '-0.19',
#          'average_price': '5186.4282',
#          'buy_price': '5105',
#          'closing_price': '5120',
#          'max_price': '5345',
#          'min_price': '4973',
#          'opening_price': '5130',
#          'sell_price': '5120',
#          'units_traded': '2139235.86886061',
#          'volume_1day': '2139235.86886061',
#          'volume_7day': '17618266.49288131'},
#  'ETC': {'24H_fluctate': '300',
#          '24H_fluctate_rate': '4.53',
#          'average_price': '6786.518',
#          'buy_price': '6910',
#          'closing_price': '6910',
#          'max_price': '7105',
#          'min_price': '6430',
#          'opening_price': '6610',
#          'sell_price': '6920',
#          'units_traded': '109384.76600036',
#          'volume_1day': '109384.76600036',
#          'volume_7day': '804661.335900136696968718'},
#  'ETH': {'24H_fluctate': '6700',
#          '24H_fluctate_rate': '2.50',
#          'average_price': '275842.9617',
#          'buy_price': '274200',
#          'closing_price': '274600',
#          'max_price': '284900',
#          'min_price': '263800',
#          'opening_price': '267900',
#          'sell_price': '274600',
#          'units_traded': '107436.17560516',
#          'volume_1day': '107436.17560516',
#          'volume_7day': '611595.584221263390676724'},
#  'ETHOS': {'24H_fluctate': '8',
#            '24H_fluctate_rate': '5.40',
#            'average_price': '152.6262',
#            'buy_price': '155',
#            'closing_price': '156',
#            'max_price': '160',
#            'min_price': '144',
#            'opening_price': '148',
#            'sell_price': '156',
#            'units_traded': '2775442.68558568',
#            'volume_1day': '2775442.68558568',
#            'volume_7day': '45327852.40303607'},
#  'ETZ': {'24H_fluctate': '8',
#          '24H_fluctate_rate': '2.73',
#          'average_price': '303.12',
#          'buy_price': '297',
#          'closing_price': '300',
#          'max_price': '318',
#          'min_price': '286',
#          'opening_price': '292',
#          'sell_price': '300',
#          'units_traded': '1257632.7248824',
#          'volume_1day': '1257632.7248824',
#          'volume_7day': '18465982.168123402404599144'},
#  'GNT': {'24H_fluctate': '2.3',
#          '24H_fluctate_rate': '3.03',
#          'average_price': '76.4221',
#          'buy_price': '76.5',
#          'closing_price': '78.1',
#          'max_price': '80',
#          'min_price': '73.3',
#          'opening_price': '75.8',
#          'sell_price': '78',
#          'units_traded': '400515.84122826',
#          'volume_1day': '400515.84122826',
#          'volume_7day': '5921812.632560664217182283'},
#  'GTO': {'24H_fluctate': '1.1',
#          '24H_fluctate_rate': '4.10',
#          'average_price': '27.7214',
#          'buy_price': '27.6',
#          'closing_price': '27.9',
#          'max_price': '29.5',
#          'min_price': '26.3',
#          'opening_price': '26.8',
#          'sell_price': '28.1',
#          'units_traded': '3001474.52787256',
#          'volume_1day': '3001474.52787256',
#          'volume_7day': '27950038.44623324'},
#  'GXC': {'24H_fluctate': '65',
#          '24H_fluctate_rate': '3.55',
#          'average_price': '1927.1694',
#          'buy_price': '1905',
#          'closing_price': '1894',
#          'max_price': '2055',
#          'min_price': '1783',
#          'opening_price': '1829',
#          'sell_price': '1923',
#          'units_traded': '137111.11694903',
#          'volume_1day': '137111.11694903',
#          'volume_7day': '1680959.77630244'},
#  'HC': {'24H_fluctate': '115',
#         '24H_fluctate_rate': '2.95',
#         'average_price': '4184.9451',
#         'buy_price': '4008',
#         'closing_price': '4007',
#         'max_price': '4500',
#         'min_price': '3835',
#         'opening_price': '3892',
#         'sell_price': '4053',
#         'units_traded': '315629.73825185',
#         'volume_1day': '315629.73825185',
#         'volume_7day': '4504974.55777643'},
#  'HDAC': {'24H_fluctate': '0.6',
#           '24H_fluctate_rate': '1.99',
#           'average_price': '30.5985',
#           'buy_price': '30.3',
#           'closing_price': '30.7',
#           'max_price': '32.5',
#           'min_price': '28.8',
#           'opening_price': '30.1',
#           'sell_price': '30.7',
#           'units_traded': '2899067.64066981',
#           'volume_1day': '2899067.64066981',
#           'volume_7day': '34337786.07394786'},
#  'HYC': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.10',
#          'average_price': '10.0068',
#          'buy_price': '9.93',
#          'closing_price': '10',
#          'max_price': '10.4',
#          'min_price': '9.73',
#          'opening_price': '9.99',
#          'sell_price': '10',
#          'units_traded': '61109123.35408012',
#          'volume_1day': '61109123.35408012',
#          'volume_7day': '1401130573.051171471'},
#  'ICX': {'24H_fluctate': '10',
#          '24H_fluctate_rate': '2.96',
#          'average_price': '343.5175',
#          'buy_price': '341',
#          'closing_price': '347',
#          'max_price': '357',
#          'min_price': '332',
#          'opening_price': '337',
#          'sell_price': '345',
#          'units_traded': '367885.79759203',
#          'volume_1day': '367885.79759203',
#          'volume_7day': '3712045.740363596870970941'},
#  'INS': {'24H_fluctate': '3',
#          '24H_fluctate_rate': '0.67',
#          'average_price': '456.1296',
#          'buy_price': '446',
#          'closing_price': '445',
#          'max_price': '488',
#          'min_price': '426',
#          'opening_price': '442',
#          'sell_price': '452',
#          'units_traded': '339314.64583019',
#          'volume_1day': '339314.64583019',
#          'volume_7day': '8533779.2929034909'},
#  'IOST': {'24H_fluctate': '0.4',
#           '24H_fluctate_rate': '3.41',
#           'average_price': '11.9108',
#           'buy_price': '12.1',
#           'closing_price': '12.1',
#           'max_price': '12.7',
#           'min_price': '11',
#           'opening_price': '11.7',
#           'sell_price': '12.2',
#           'units_traded': '3351017.5125255',
#           'volume_1day': '3351017.5125255',
#           'volume_7day': '39954972.37965144034281569'},
#  'ITC': {'24H_fluctate': '12',
#          '24H_fluctate_rate': '3.52',
#          'average_price': '355.8331',
#          'buy_price': '352',
#          'closing_price': '352',
#          'max_price': '375',
#          'min_price': '323',
#          'opening_price': '340',
#          'sell_price': '356',
#          'units_traded': '1533621.34348889',
#          'volume_1day': '1533621.34348889',
#          'volume_7day': '22401258.092399064799352276'},
#  'KNC': {'24H_fluctate': '12',
#          '24H_fluctate_rate': '5.58',
#          'average_price': '225.652',
#          'buy_price': '225',
#          'closing_price': '227',
#          'max_price': '247',
#          'min_price': '213',
#          'opening_price': '215',
#          'sell_price': '228',
#          'units_traded': '512546.85945415',
#          'volume_1day': '512546.85945415',
#          'volume_7day': '5429129.86689698425300172'},
#  'LBA': {'24H_fluctate': '-0.5',
#          '24H_fluctate_rate': '-1.62',
#          'average_price': '31.1537',
#          'buy_price': '30.2',
#          'closing_price': '30.2',
#          'max_price': '32.3',
#          'min_price': '29.9',
#          'opening_price': '30.7',
#          'sell_price': '30.4',
#          'units_traded': '9316721.85609058',
#          'volume_1day': '9316721.85609058',
#          'volume_7day': '96865307.02153059765145354'},
#  'LINK': {'24H_fluctate': '48',
#           '24H_fluctate_rate': '1.06',
#           'average_price': '4680.5802',
#           'buy_price': '4561',
#           'closing_price': '4567',
#           'max_price': '4940',
#           'min_price': '4434',
#           'opening_price': '4519',
#           'sell_price': '4600',
#           'units_traded': '358311.64679819',
#           'volume_1day': '358311.64679819',
#           'volume_7day': '5097127.647993949339358063'},
#  'LOOM': {'24H_fluctate': '1.3',
#           '24H_fluctate_rate': '1.49',
#           'average_price': '87.3402',
#           'buy_price': '88.2',
#           'closing_price': '88.3',
#           'max_price': '91.5',
#           'min_price': '81.9',
#           'opening_price': '87',
#           'sell_price': '88.3',
#           'units_traded': '488091.28578112',
#           'volume_1day': '488091.28578112',
#           'volume_7day': '4382628.19842006979771485'},
#  'LRC': {'24H_fluctate': '-1.6',
#          '24H_fluctate_rate': '-2.09',
#          'average_price': '73.2402',
#          'buy_price': '72.1',
#          'closing_price': '74.9',
#          'max_price': '80.8',
#          'min_price': '70.1',
#          'opening_price': '76.5',
#          'sell_price': '74.9',
#          'units_traded': '555954.63258488',
#          'volume_1day': '555954.63258488',
#          'volume_7day': '5587940.271129428809595789'},
#  'LTC': {'24H_fluctate': '800',
#          '24H_fluctate_rate': '0.75',
#          'average_price': '108612.7063',
#          'buy_price': '107100',
#          'closing_price': '107300',
#          'max_price': '112200',
#          'min_price': '103500',
#          'opening_price': '106500',
#          'sell_price': '107500',
#          'units_traded': '21841.14943896',
#          'volume_1day': '21841.14943896',
#          'volume_7day': '175944.325248'},
#  'MCO': {'24H_fluctate': '40',
#          '24H_fluctate_rate': '0.66',
#          'average_price': '6062.7545',
#          'buy_price': '6055',
#          'closing_price': '6065',
#          'max_price': '6300',
#          'min_price': '5790',
#          'opening_price': '6025',
#          'sell_price': '6145',
#          'units_traded': '43184.11784906',
#          'volume_1day': '43184.11784906',
#          'volume_7day': '256739.64506217'},
#  'MITH': {'24H_fluctate': '-0.9',
#           '24H_fluctate_rate': '-1.90',
#           'average_price': '46.9314',
#           'buy_price': '45.9',
#           'closing_price': '46.4',
#           'max_price': '49.4',
#           'min_price': '45',
#           'opening_price': '47.3',
#           'sell_price': '46.6',
#           'units_traded': '3447494.70780772',
#           'volume_1day': '3447494.70780772',
#           'volume_7day': '15877506.35922620334584781'},
#  'MIX': {'24H_fluctate': '-2.1',
#          '24H_fluctate_rate': '-3.06',
#          'average_price': '67.1363',
#          'buy_price': '66.5',
#          'closing_price': '66.5',
#          'max_price': '69.6',
#          'min_price': '64.3',
#          'opening_price': '68.6',
#          'sell_price': '67.1',
#          'units_traded': '2733154.69626884',
#          'volume_1day': '2733154.69626884',
#          'volume_7day': '40305468.879543152128637568'},
#  'MTL': {'24H_fluctate': '180',
#          '24H_fluctate_rate': '9.31',
#          'average_price': '2073.3062',
#          'buy_price': '2089',
#          'closing_price': '2113',
#          'max_price': '2313',
#          'min_price': '1877',
#          'opening_price': '1933',
#          'sell_price': '2110',
#          'units_traded': '138544.07022698',
#          'volume_1day': '138544.07022698',
#          'volume_7day': '638081.54421716'},
#  'NPXS': {'24H_fluctate': '0.06',
#           '24H_fluctate_rate': '8.21',
#           'average_price': '0.7759',
#           'buy_price': '0.77',
#           'closing_price': '0.79',
#           'max_price': '0.82',
#           'min_price': '0.71',
#           'opening_price': '0.73',
#           'sell_price': '0.78',
#           'units_traded': '539963146.5969872',
#           'volume_1day': '539963146.5969872',
#           'volume_7day': '3230581714.227932208350640193'},
#  'OCN': {'24H_fluctate': '0.1',
#          '24H_fluctate_rate': '3.19',
#          'average_price': '3.2602',
#          'buy_price': '3.23',
#          'closing_price': '3.23',
#          'max_price': '3.46',
#          'min_price': '3.09',
#          'opening_price': '3.13',
#          'sell_price': '3.27',
#          'units_traded': '12541667.55457508',
#          'volume_1day': '12541667.55457508',
#          'volume_7day': '147785247.519534292031302212'},
#  'OMG': {'24H_fluctate': '5',
#          '24H_fluctate_rate': '0.26',
#          'average_price': '1880.6326',
#          'buy_price': '1845',
#          'closing_price': '1861',
#          'max_price': '1960',
#          'min_price': '1774',
#          'opening_price': '1856',
#          'sell_price': '1862',
#          'units_traded': '538984.24591199',
#          'volume_1day': '538984.24591199',
#          'volume_7day': '3247476.75519715027697645'},
#  'ORBS': {'24H_fluctate': '-0.09',
#           '24H_fluctate_rate': '-0.34',
#           'average_price': '29.715',
#           'buy_price': '29.3',
#           'closing_price': '29.3',
#           'max_price': '31',
#           'min_price': '28.6',
#           'opening_price': '29.4',
#           'sell_price': '29.6',
#           'units_traded': '17359271.8547294',
#           'volume_1day': '17359271.8547294',
#           'volume_7day': '130553691.030861028319004324'},
#  'PAY': {'24H_fluctate': '18',
#          '24H_fluctate_rate': '7.00',
#          'average_price': '272.6775',
#          'buy_price': '273',
#          'closing_price': '275',
#          'max_price': '290',
#          'min_price': '255',
#          'opening_price': '257',
#          'sell_price': '275',
#          'units_traded': '183265.69783513',
#          'volume_1day': '183265.69783513',
#          'volume_7day': '3310387.23801745684417128'},
#  'PIVX': {'24H_fluctate': '229',
#           '24H_fluctate_rate': '13.12',
#           'average_price': '1978.8586',
#           'buy_price': '1930',
#           'closing_price': '1974',
#           'max_price': '2228',
#           'min_price': '1723',
#           'opening_price': '1745',
#           'sell_price': '1982',
#           'units_traded': '77678.2594423',
#           'volume_1day': '77678.2594423',
#           'volume_7day': '653513.90580925'},
#  'PLY': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '13.7521',
#          'buy_price': '13.5',
#          'closing_price': '13.6',
#          'max_price': '14.4',
#          'min_price': '13.3',
#          'opening_price': '13.6',
#          'sell_price': '13.7',
#          'units_traded': '36786049.61299597',
#          'volume_1day': '36786049.61299597',
#          'volume_7day': '307017671.465806902'},
#  'POLY': {'24H_fluctate': '7',
#           '24H_fluctate_rate': '10.93',
#           'average_price': '75.5436',
#           'buy_price': '70.2',
#           'closing_price': '71',
#           'max_price': '88',
#           'min_price': '63',
#           'opening_price': '64',
#           'sell_price': '70.9',
#           'units_traded': '16254098.67437614',
#           'volume_1day': '16254098.67437614',
#           'volume_7day': '40586196.666001743308759825'},
#  'POWR': {'24H_fluctate': '1.7',
#           '24H_fluctate_rate': '1.73',
#           'average_price': '98.0302',
#           'buy_price': '99',
#           'closing_price': '99.9',
#           'max_price': '103',
#           'min_price': '92',
#           'opening_price': '98.2',
#           'sell_price': '99.9',
#           'units_traded': '1021192.87567166',
#           'volume_1day': '1021192.87567166',
#           'volume_7day': '7707675.94334943'},
#  'PPT': {'24H_fluctate': '141',
#          '24H_fluctate_rate': '4.31',
#          'average_price': '3445.4539',
#          'buy_price': '3405',
#          'closing_price': '3410',
#          'max_price': '3646',
#          'min_price': '3238',
#          'opening_price': '3269',
#          'sell_price': '3410',
#          'units_traded': '117593.45846141',
#          'volume_1day': '117593.45846141',
#          'volume_7day': '1866193.19676153'},
#  'PST': {'24H_fluctate': '16',
#          '24H_fluctate_rate': '12.21',
#          'average_price': '145.381',
#          'buy_price': '146',
#          'closing_price': '147',
#          'max_price': '157',
#          'min_price': '126',
#          'opening_price': '131',
#          'sell_price': '147',
#          'units_traded': '5243507.54432081',
#          'volume_1day': '5243507.54432081',
#          'volume_7day': '21503000.368464452474168705'},
#  'QTUM': {'24H_fluctate': '189',
#           '24H_fluctate_rate': '5.02',
#           'average_price': '3936.0764',
#           'buy_price': '3938',
#           'closing_price': '3950',
#           'max_price': '4152',
#           'min_price': '3691',
#           'opening_price': '3761',
#           'sell_price': '3947',
#           'units_traded': '457372.37148686',
#           'volume_1day': '457372.37148686',
#           'volume_7day': '3662262.69739371'},
#  'RDN': {'24H_fluctate': '81',
#          '24H_fluctate_rate': '8.81',
#          'average_price': '996.952',
#          'buy_price': '1000',
#          'closing_price': '1000',
#          'max_price': '1116',
#          'min_price': '876',
#          'opening_price': '919',
#          'sell_price': '1012',
#          'units_traded': '349957.17072998',
#          'volume_1day': '349957.17072998',
#          'volume_7day': '1970761.923579092717018458'},
#  'REP': {'24H_fluctate': '1810',
#          '24H_fluctate_rate': '9.93',
#          'average_price': '20649.192',
#          'buy_price': '19650',
#          'closing_price': '20020',
#          'max_price': '24700',
#          'min_price': '18030',
#          'opening_price': '18210',
#          'sell_price': '20020',
#          'units_traded': '60402.91412207',
#          'volume_1day': '60402.91412207',
#          'volume_7day': '185452.585942127035504132'},
#  'RNT': {'24H_fluctate': '1.3',
#          '24H_fluctate_rate': '3.14',
#          'average_price': '41.8038',
#          'buy_price': '42.3',
#          'closing_price': '42.6',
#          'max_price': '43.9',
#          'min_price': '40.5',
#          'opening_price': '41.3',
#          'sell_price': '42.6',
#          'units_traded': '2098106.32273142',
#          'volume_1day': '2098106.32273142',
#          'volume_7day': '29764749.221598959215133828'},
#  'ROM': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '0.0446',
#          'buy_price': '0.04',
#          'closing_price': '0.04',
#          'max_price': '0.05',
#          'min_price': '0.04',
#          'opening_price': '0.04',
#          'sell_price': '0.05',
#          'units_traded': '1204287188.67148',
#          'volume_1day': '1204287188.67148',
#          'volume_7day': '19434916974.175240000000000002'},
#  'SALT': {'24H_fluctate': '3',
#           '24H_fluctate_rate': '1.43',
#           'average_price': '212.1872',
#           'buy_price': '211',
#           'closing_price': '212',
#           'max_price': '228',
#           'min_price': '203',
#           'opening_price': '209',
#           'sell_price': '212',
#           'units_traded': '399004.05913',
#           'volume_1day': '399004.05913',
#           'volume_7day': '2691980.13915264'},
#  'SNT': {'24H_fluctate': '0.7',
#          '24H_fluctate_rate': '2.89',
#          'average_price': '24.8454',
#          'buy_price': '24.9',
#          'closing_price': '24.9',
#          'max_price': '26.1',
#          'min_price': '23.7',
#          'opening_price': '24.2',
#          'sell_price': '25.3',
#          'units_traded': '4818550.3156606',
#          'volume_1day': '4818550.3156606',
#          'volume_7day': '53507167.15746821656894206'},
#  'STEEM': {'24H_fluctate': '-7',
#            '24H_fluctate_rate': '-1.78',
#            'average_price': '396.2057',
#            'buy_price': '388',
#            'closing_price': '385',
#            'max_price': '412',
#            'min_price': '375',
#            'opening_price': '392',
#            'sell_price': '394',
#            'units_traded': '642763.0823111',
#            'volume_1day': '642763.0823111',
#            'volume_7day': '12049516.34727131'},
#  'STRAT': {'24H_fluctate': '100',
#            '24H_fluctate_rate': '7.29',
#            'average_price': '1482.3972',
#            'buy_price': '1470',
#            'closing_price': '1470',
#            'max_price': '1600',
#            'min_price': '1351',
#            'opening_price': '1370',
#            'sell_price': '1478',
#            'units_traded': '255369.66834282',
#            'volume_1day': '255369.66834282',
#            'volume_7day': '1697552.11978857'},
#  'THETA': {'24H_fluctate': '2',
#            '24H_fluctate_rate': '1.80',
#            'average_price': '114.7156',
#            'buy_price': '113',
#            'closing_price': '113',
#            'max_price': '122',
#            'min_price': '110',
#            'opening_price': '111',
#            'sell_price': '115',
#            'units_traded': '724870.66696316',
#            'volume_1day': '724870.66696316',
#            'volume_7day': '5969820.658896666985828777'},
#  'TMTG': {'24H_fluctate': '0.03',
#           '24H_fluctate_rate': '1.38',
#           'average_price': '2.1859',
#           'buy_price': '2.18',
#           'closing_price': '2.19',
#           'max_price': '2.27',
#           'min_price': '2.07',
#           'opening_price': '2.16',
#           'sell_price': '2.19',
#           'units_traded': '48719693.86064638',
#           'volume_1day': '48719693.86064638',
#           'volume_7day': '284658407.165542867958841878'},
#  'TRUE': {'24H_fluctate': '3',
#           '24H_fluctate_rate': '0.55',
#           'average_price': '554.9',
#           'buy_price': '538',
#           'closing_price': '541',
#           'max_price': '598',
#           'min_price': '515',
#           'opening_price': '538',
#           'sell_price': '543',
#           'units_traded': '528769.89380368',
#           'volume_1day': '528769.89380368',
#           'volume_7day': '4485264.735044593020669752'},
#  'TRX': {'24H_fluctate': '0.6',
#          '24H_fluctate_rate': '2.09',
#          'average_price': '29.3928',
#          'buy_price': '29.2',
#          'closing_price': '29.2',
#          'max_price': '30.3',
#          'min_price': '28.4',
#          'opening_price': '28.6',
#          'sell_price': '29.3',
#          'units_traded': '70888315.57778942',
#          'volume_1day': '70888315.57778942',
#          'volume_7day': '570446062.15395638'},
#  'VALOR': {'24H_fluctate': '110',
#            '24H_fluctate_rate': '4.44',
#            'average_price': '2564.249',
#            'buy_price': '2555',
#            'closing_price': '2585',
#            'max_price': '2696',
#            'min_price': '2409',
#            'opening_price': '2475',
#            'sell_price': '2585',
#            'units_traded': '102889.2864675',
#            'volume_1day': '102889.2864675',
#            'volume_7day': '1142499.672393602869914978'},
#  'VET': {'24H_fluctate': '0.31',
#          '24H_fluctate_rate': '4.27',
#          'average_price': '7.4403',
#          'buy_price': '7.55',
#          'closing_price': '7.56',
#          'max_price': '7.78',
#          'min_price': '7.19',
#          'opening_price': '7.25',
#          'sell_price': '7.6',
#          'units_traded': '14230056.05407113',
#          'volume_1day': '14230056.05407113',
#          'volume_7day': '137995060.145939665291439038'},
#  'WAVES': {'24H_fluctate': '554',
#            '24H_fluctate_rate': '26.43',
#            'average_price': '2738.8906',
#            'buy_price': '2616',
#            'closing_price': '2650',
#            'max_price': '3250',
#            'min_price': '2075',
#            'opening_price': '2096',
#            'sell_price': '2667',
#            'units_traded': '809218.74760782',
#            'volume_1day': '809218.74760782',
#            'volume_7day': '1418753.64029412'},
#  'WAX': {'24H_fluctate': '1',
#          '24H_fluctate_rate': '1.58',
#          'average_price': '64.4904',
#          'buy_price': '64.2',
#          'closing_price': '64.2',
#          'max_price': '70',
#          'min_price': '61.9',
#          'opening_price': '63.2',
#          'sell_price': '65.1',
#          'units_traded': '1854909.57613427',
#          'volume_1day': '1854909.57613427',
#          'volume_7day': '17525593.01038612'},
#  'WET': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '15.2714',
#          'buy_price': '15.2',
#          'closing_price': '15.3',
#          'max_price': '15.8',
#          'min_price': '14.8',
#          'opening_price': '15.3',
#          'sell_price': '15.3',
#          'units_traded': '11132757.98541207',
#          'volume_1day': '11132757.98541207',
#          'volume_7day': '129250306.908702978303497485'},
#  'WTC': {'24H_fluctate': '17',
#          '24H_fluctate_rate': '0.65',
#          'average_price': '2755.2456',
#          'buy_price': '2618',
#          'closing_price': '2617',
#          'max_price': '3105',
#          'min_price': '2551',
#          'opening_price': '2600',
#          'sell_price': '2650',
#          'units_traded': '235068.68629594',
#          'volume_1day': '235068.68629594',
#          'volume_7day': '5300304.465247762054603445'},
#  'XEM': {'24H_fluctate': '4.9',
#          '24H_fluctate_rate': '5.15',
#          'average_price': '98.6345',
#          'buy_price': '98.6',
#          'closing_price': '100',
#          'max_price': '104',
#          'min_price': '92.7',
#          'opening_price': '95.1',
#          'sell_price': '100',
#          'units_traded': '1084449.68377478',
#          'volume_1day': '1084449.68377478',
#          'volume_7day': '12223508.27773851'},
#  'XLM': {'24H_fluctate': '3',
#          '24H_fluctate_rate': '2.72',
#          'average_price': '112.4019',
#          'buy_price': '111',
#          'closing_price': '113',
#          'max_price': '117',
#          'min_price': '107',
#          'opening_price': '110',
#          'sell_price': '113',
#          'units_traded': '2747477.86489351',
#          'volume_1day': '2747477.86489351',
#          'volume_7day': '23308518.48095933'},
#  'XMR': {'24H_fluctate': '8050',
#          '24H_fluctate_rate': '8.56',
#          'average_price': '97063.993',
#          'buy_price': '101400',
#          'closing_price': '102000',
#          'max_price': '107700',
#          'min_price': '92450',
#          'opening_price': '93950',
#          'sell_price': '102100',
#          'units_traded': '2837616.52507081',
#          'volume_1day': '2837616.52507081',
#          'volume_7day': '17505923.348707920282'},
#  'XRP': {'24H_fluctate': '2',
#          '24H_fluctate_rate': '0.53',
#          'average_price': '379.3185',
#          'buy_price': '376',
#          'closing_price': '376',
#          'max_price': '391',
#          'min_price': '369',
#          'opening_price': '374',
#          'sell_price': '377',
#          'units_traded': '82842142.6146906',
#          'volume_1day': '82842142.6146906',
#          'volume_7day': '648898810.40910068'},
#  'XVG': {'24H_fluctate': '0.5',
#          '24H_fluctate_rate': '3.44',
#          'average_price': '14.7194',
#          'buy_price': '14.7',
#          'closing_price': '15',
#          'max_price': '15.7',
#          'min_price': '13.9',
#          'opening_price': '14.5',
#          'sell_price': '15',
#          'units_traded': '1621965.92072629',
#          'volume_1day': '1621965.92072629',
#          'volume_7day': '21617853.61778351'},
#  'ZEC': {'24H_fluctate': '13000',
#          '24H_fluctate_rate': '12.62',
#          'average_price': '106034.9954',
#          'buy_price': '116000',
#          'closing_price': '116000',
#          'max_price': '118300',
#          'min_price': '96200',
#          'opening_price': '103000',
#          'sell_price': '117200',
#          'units_traded': '2467.11013041',
#          'volume_1day': '2467.11013041',
#          'volume_7day': '15882.85615669'},
#  'ZIL': {'24H_fluctate': '0.4',
#          '24H_fluctate_rate': '2.42',
#          'average_price': '16.9844',
#          'buy_price': '16.9',
#          'closing_price': '16.9',
#          'max_price': '17.5',
#          'min_price': '16.3',
#          'opening_price': '16.5',
#          'sell_price': '17',
#          'units_traded': '7191585.97427006',
#          'volume_1day': '7191585.97427006',
#          'volume_7day': '61637832.343998164443'},
#  'ZRX': {'24H_fluctate': '43',
#          '24H_fluctate_rate': '16.53',
#          'average_price': '305.4586',
#          'buy_price': '302',
#          'closing_price': '303',
#          'max_price': '328',
#          'min_price': '260',
#          'opening_price': '260',
#          'sell_price': '306',
#          'units_traded': '1618001.58585247',
#          'volume_1day': '1618001.58585247',
#          'volume_7day': '4613679.577089674745890539'},
#  'date': '1563256770164'}

# %%
for market in data.keys():
    if market != 'data':
        gap = float(data[market]['max_price']) - float(data[market]['min_price'])
        if float(data[market]['opening_price']) + gap > float(data[market]['max_price']):
            print(f'{market}은 상승장')
        else:
            print(f'{market}은 하락장')
# Out:
# BTC은 상승장
# ETH은 상승장
# DASH은 상승장
# LTC은 상승장
# ETC은 상승장
# XRP은 상승장
# BCH은 상승장
# XMR은 상승장
# ZEC은 상승장
# QTUM은 상승장
# BTG은 상승장
# EOS은 상승장
# ICX은 상승장
# VET은 상승장
# TRX은 상승장
# ELF은 상승장
# MITH은 상승장
# MCO은 상승장
# OMG은 상승장
# KNC은 상승장
# GNT은 상승장
# ZIL은 상승장
# ETHOS은 상승장
# PAY은 상승장
# WAX은 상승장
# POWR은 상승장
# LRC은 상승장
# GTO은 상승장
# STEEM은 상승장
# STRAT은 상승장
# ZRX은 상승장
# REP은 상승장
# AE은 상승장
# XEM은 상승장
# SNT은 상승장
# ADA은 상승장
# PPT은 상승장
# CTXC은 상승장
# CMT은 상승장
# THETA은 상승장
# WTC은 상승장
# ITC은 상승장
# TRUE은 상승장
# ABT은 상승장
# RNT은 상승장
# PLY은 상승장
# WAVES은 상승장
# LINK은 상승장
# ENJ은 상승장
# PST은 상승장
# SALT은 상승장
# RDN은 상승장
# LOOM은 상승장
# PIVX은 상승장
# INS은 상승장
# BCD은 상승장
# BZNT은 상승장
# XLM은 상승장
# OCN은 상승장
# BSV은 상승장
# TMTG은 상승장
# BAT은 상승장
# WET은 상승장
# XVG은 상승장
# IOST은 상승장
# POLY은 상승장
# HC은 상승장
# ROM은 하락장
# AMO은 상승장
# ETZ은 상승장
# ARN은 상승장
# APIS은 상승장
# MTL은 상승장
# DACC은 상승장
# DAC은 상승장
# BHP은 상승장
# BTT은 상승장
# HDAC은 상승장
# NPXS은 상승장
# AUTO은 상승장
# GXC은 상승장
# ORBS은 상승장
# VALOR은 상승장
# CON은 상승장
# ANKR은 상승장
# MIX은 상승장
# HYC은 상승장
# LBA은 상승장
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-1622d0ce7c53> in <module>
#       1 for market in data.keys():
#       2     if market != 'data':
# ----> 3         gap = float(data[market]['max_price']) - float(data[market]['min_price'])
#       4         if float(data[market]['opening_price']) + gap > float(data[market]['max_price']):
#       5             print(f'{market}은 상승장')
#
# TypeError: string indices must be integers

# %%
for coin, coin_data in data.itmes():
#     if type(coin_data) != type(dict()):
#         continue
    if type(coin_data) == type(dict()):
        if float(coin_data['opening_price']) - float(coin_data['min_price']) > 0:
            print('상승장')
        else:
            print('하락장')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-93-6bfc7db08acb> in <module>
# ----> 1 for coin, coin_data in data.itmes():
#       2 #     if type(coin_data) != type(dict()):
#       3 #         continue
#       4     if type(coin_data) == type(dict()):
#       5         if float(coin_data['opening_price']) - float(coin_data['min_price']) > 0:
#
# AttributeError: 'dict' object has no attribute 'itmes'

# %% [markdown]
# # 평균점수
# > 다음 딕셔너리에서 평균 점수를 출력하라

# %%
student = {'python':80, 'algorithm':78, 'django':95, 'flask':80}
sum = 0
for key, value in student.items():
    sum += value
print(f'평균 점수는 {sum/len(student)}점')
# Out:
# 평균 점수는 83.25점

# %%
count = 0
total_score = 0
for score in student.values():
    total_score += score
    count += 1
print(total_score/count)
# Out:
# 83.25

# %%
list(student.values())
# Out:
# [80, 78, 95, 80]

# %% [markdown]
# # 혈액형
# > 학생들의 혈액형(A,B,O,AB)에 대한 데이터가 리스트에 들어있다. 각 혈액형이 몇명인지 딕셔너리를 만들어 출력하라

# %%
blood = ['A','A','B','O','A','B','A','AB','AB','O','A','O','AB','O']
my_dict = {'A' : blood.count('A'), 'B': blood.count('B'), 'O': blood.count('O'), 'AB': blood.count('AB')}
print(my_dict)

blood_type = {'A' : 0, 'B' : 0, 'O' : 0, 'AB' : 0}
for i in blood:
    if i in blood_type:
        blood_type[i] += 1
print(blood_type)
# Out:
# {'A': 5, 'B': 2, 'O': 4, 'AB': 3}
# {'A': 5, 'B': 2, 'O': 4, 'AB': 3}

# %%
a = b = ab = o = 0

for blood_type in blood:
    if blood_type == 'A':
        a += 1
    elif blood_type == 'B':
        b += 1
    elif blood_type == 'AB':
        ab += 1
    else:
        o += 1
print({'A': a, 'B': b, 'AB': ab, 'O': o})
# Out:
# {'A': 5, 'B': 2, 'AB': 3, 'O': 4}

# %%
# 2번째 방법
blood_dict = {}

# (반복)하나씩 꺼내서 확인한다.
for blood_type in blood:
    # 지금 나온 적이 없으면, 키와 value 1로 만든다.
    if blood_type not in blood_dict.keys():
        blood_dict[blood_type] = 1
    else:
        blood_dict[blood_type] += 1
print(blood_dict)
# Out:
# {'A': 5, 'B': 2, 'O': 4, 'AB': 3}

# %%
{blood_type: blood.count(blood_type) for blood_type in set(blood)}
# Out:
# {'O': 4, 'A': 5, 'B': 2, 'AB': 3}

# %% [markdown]
# # UBD
# > movies는 영화제목이 key로 누적관객수가 value인 딕셔너리이다.
# >
# > 자전차왕 엄복동의 누적관객수는 172212명이고 172212명을 1UBD라고 할때 80UBD를 넘지 못하는 영화를 출력하라.

# %%
movies = {
    "7번방의선물":12811206,
    "괴물":13019740,
    "국제시장":14257115,
    "극한직업":16261018,
    "도둑들":12983330,
    "명량":17613682,
    "베테랑":13414009,
    "신과함께-죄와벌":14410754,
    "아바타":13624328,
    "어벤져스:엔드게임":13901423,
}
ubd = 172212
# ver1
mang = '80UBD을 넘지 못하는 영화는'
mang_list = []
for movie in movies.keys():
    if movies[movie] < 80*ubd:
        mang = mang +' '+ movie
        mang_list.append(movie)
print(f'{mang}입니다')

print('80UBD을 넘지 못하는 영화는 ', end='')
for i in mang_list:
    print(i, end=' ')
print('입니다')

for movie in movies.keys():
    print(movie, end=' ') if movies[movie] < 80*ubd else None
# Out:
# 80UBD을 넘지 못하는 영화는 7번방의선물 괴물 도둑들 베테랑 아바타입니다
# 80UBD을 넘지 못하는 영화는 7번방의선물 괴물 도둑들 베테랑 아바타 입니다
# 7번방의선물 괴물 도둑들 베테랑 아바타

# %%
for movie, count in movies.items():
    if count / 172212 < 80:
        print(movie)
# Out:
# 7번방의선물
# 괴물
# 도둑들
# 베테랑
# 아바타
